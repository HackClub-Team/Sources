# %% [markdown]
# **Booleans**
# * Booleans are operators that allow you to convey **True** or **False** statements

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
1 > 2
# Out:
# False

# %%
1 == 1
# Out:
# True
