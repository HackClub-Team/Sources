# %% [markdown]
# **Dictionaries**
# * Dictionaries are unordered mappings for storing objects. Previously we saw how lists store objects in an ordered sequence, dictionaries use a key-value pairing instead
# * This key-value pair allows users to quickly grab objects without needing to know an index location
# * Dictionaries use curly braces and colons to signify the keys and their associated values
# > * {"key1" : "value1", "key2" : "value2"}
# * Difference between Dictionaries and Lists
# > * Dictionaries: Objects retrieved by key name. Unordered and can't be sorted
# > * Lists: Objects retrieved by location. Ordered sequence that can be indexed or sliced

# %%
my_dict = {"key1" : "value1", "key2" : "value2"}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict["key1"]
# Out:
# 'value1'

# %%
prices_lookup = {"apple" : 2.99, "oranges" : 1.99, "milk" : 5.80}

# %%
prices_lookup["apple"]
# Out:
# 2.99

# %%
d = {"k1" : 123, "k2" : [0, 1, 2], "k3" : {"insideKey" : 100}}

# %%
d["k2"]
# Out:
# [0, 1, 2]

# %%
d["k3"]
# Out:
# {'insideKey': 100}

# %%
d["k3"]["insideKey"]
# Out:
# 100

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values([123, [0, 1, 2], {'insideKey': 100}])

# %%
d.items()
# Out:
# dict_items([('k1', 123), ('k2', [0, 1, 2]), ('k3', {'insideKey': 100})])
