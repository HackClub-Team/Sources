# %% [markdown]
# **Comparison Operators**
# * **==**
# > * If the values of two operands are equal, than the condition becomes true
# > * **(3 == 4)** is not true
# * **!=**
# > * If the values of two operands are not equal, than the condition becomes true
# > * **(3 != 4)** is true
# * **>**
# > * If the value of the left operand is greater than the value of the right operand, then the condition becomes true
# > * **(3 > 4)** is not true
# * **<**
# > * If the value of the left operand is less than the value of the right operand, then the condition becomes true
# > * **(3 < 4)** is true
# * **>=**
# > * If the value of the left operand is greater than or equal to the value of the right operand, then the condition becomes true
# > * **(3 >= 4)** is not true
# * **<=**
# > * If the value of the left operand is less than or equal to the value of the right operand, then the condition becomes true
# > * **(3 <= 4)** is not true

# %%
2 == 2
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
"hello" == "bye"
# Out:
# False

# %%
"Bye" == "bye"
# Out:
# False

# %%
"2" == 2
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %%
3 != 3
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
2 > 1
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %%
4 <= 1
# Out:
# False

# %%
1 < 2 > 3
# Out:
# False

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
"h" == "h" and 2 == 2
# Out:
# True

# %%
100 == 1 or 2 == 200
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
not 400 > 500
# Out:
# True
